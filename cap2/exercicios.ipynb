# %% [markdown]
# # Exercícios - Cap 2
# ## Conceptual

# %% [markdown]
# 1.
# a) Modelos flexíveis irão atuar melhor, com dados suficientes terão maior capacidade de predição que modelos mais regularizados.
#
# b) Modelos regularizados irão atuar melhor aqui. Alta variãncia, dessa forma é necessário reduzir esse ponto.
#
# c) Modelos flexíveis tendem a ser não lineares então performam melhor em casos como esse.
#
# e) Como nosso problema já possui alta variância é necessário atuar com algum modelo que lide melhor com esse problema, dessa forma modelos regularizados irão atuar melhor aqui, diminuindo a variância existente em troca de aumento de víes.

# %% [markdown]
# 2.
# a) Problema de regressão (estimar salário do CEO), foco em inferência (entendimento como diferentes features afetam o salário do CEO). n = 500 (número de firmas), p = 4 (features)
#
# b) Problema de classificação (binário), foco em predição, n = 20, p = 14
#
# c) Problema de regressão, foco em predição, n = # semanas no ano de 2012, p = 4

# %% [markdown]
# 3.
# a.) Irei descrever como a função se move em um gráfico onde x-axis é igual a flexibilidade do modelo, onde temos aumento de flexibilidade.
#
# Bias ->  Tende a diminuir com aumento de flexibilização
#
# Variance -> Tende a aumentar com aumento de flexibilização
#
# Training error -> Tende a diminuir com aumento de flexibilização (até overfitting)
#
# Test error -> Formato de U onde erro diminui até certo ponto e depois volta a aumentar
#
# Bayes error -> Erro estável independente do modelo.
#
# b.) Explicação do formato das curvas
#
# Bias -> Com maior flexibilização o modelo se "aproxima" mais de cada ponto de dado, diminuindo o bias médio do modelo
#
# Variance -> Com maior flexibilização cada ponto de dado possui poder maior de como atuar na estimação do modeo.
#
# Training error -> Apenas diminui com aumento de flexibilização, até o ponto onde o modelo preve exatamente cada ponto de dado em treino mas é incapaz de generalizar para teste
#
# Test error -> Formato de U pois com aumento de flexibilização o modelo é capaz de encontrar padrões mais complexos, até o ponto onde o modelo começa a encontrar padrão no ruído
#
# Bayes error -> O erro de Bayes corresponde ao erro mínimo irredutível, determinado exclusivamente pela variância do ruído nos dados

# %% [markdown]
# 4.
# a)
# 1 -

# %% [markdown]
# 5.
# Modelos com maior flexibilidade permitem ajuste maior a cada ponto de dado, isso significa menor erro porém maior variãncia. Dessa forma modelos com maior flexibilidade podem encontrar padrões mais complexos nos dados, porém estão sujeitos a encontrar padrões existentes apenas devido a ruído, o que chamamos de overfitting.
# Modelos flexíveis tendem a performar melhor em situações com dados não lineares, com n grande e dados pouco ruidosos.
# Modelos menos flexívies tendem a performar melhor com dados lineares, e com dados com alto ruído.

# %% [markdown]
# 6.
# Modelos paramétricos assumem a priori uma forma funcional específica para a função geradora dos dados 𝑓(𝑋). Essa suposição reduz o problema de aprendizado à estimação de um número fixo e finito de parâmetros, independentemente do tamanho da amostra. Caso a forma funcional assumida esteja incorreta, o modelo pode apresentar alto viés e desempenho ruim.
#
# Modelos não paramétricos, por outro lado, não especificam explicitamente a forma funcional de 𝑓(𝑋). Em vez disso, permitem que a complexidade do modelo cresça com o tamanho da amostra, buscando aprender a estrutura dos dados de forma mais flexível.
#
#
# **Paramétricos**
#
# Vantagens
# - Simples
# - Poucos dados
# - Interpretáveis
#
# Desvantagens
# - Pouca flexibilidade
# - Alto viés
#
# **Não Paramétricos**
#
# Vantagens
# - Flexíveis
# - Menor viés
#
# Desvantagens
# - Precisam de muitos dados
# - Alta variância

# %% [markdown]
# 7.
# a)
#
# 1: 3
#
# 2: 2
#
# 3: sqrt(10)
#
# 4: sqrt(5)
#
# 5: sqrt(2)
#
# 6: sqrt(3)
#
# b) Previsão é verde, pois define apenas considerando vizinho mais próximo obs-5
#
# c) Previsão é vermelho, pois considera 3 vizinhos mais próximos sendo obs-{2, 5, 6}
#
# d) No caso de dados altamente não lineares, o valor de K deve ser baixo para pois para KNN quanto menor K mais fléxivel o modelo. Em problemas com fronteiras de decisão altamente não lineares, valores pequenos de K tornam o kNN mais flexível, permitindo capturar estruturas locais complexas, embora com maior variância.

# %% [markdown]
# ## Applied

# %% [markdown]
# ### 8.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

df = pd.read_csv(r"../data/College.csv")
df.head(5)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
df = df.rename(columns={"Unnamed: 0": "College"})
df = df.set_index("College")
df.head(3)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# College
# Abilene Christian University        3300    450      2200   70        78
# Adelphi University                  6450    750      1500   29        30
# Adrian College                      3750    400      1165   53        66
#
# ...

# %%
df.describe().T
# Out:
#              count          mean          std     min     25%     50%  \
# Apps         777.0   3001.638353  3870.201484    81.0   776.0  1558.0
# Accept       777.0   2018.804376  2451.113971    72.0   604.0  1110.0
# Enroll       777.0    779.972973   929.176190    35.0   242.0   434.0
# Top10perc    777.0     27.558559    17.640364     1.0    15.0    23.0
# Top25perc    777.0     55.796654    19.804778     9.0    41.0    54.0
# F.Undergrad  777.0   3699.907336  4850.420531   139.0   992.0  1707.0
# P.Undergrad  777.0    855.298584  1522.431887     1.0    95.0   353.0
# Outstate     777.0  10440.669241  4023.016484  2340.0  7320.0  9990.0
# Room.Board   777.0   4357.526384  1096.696416  1780.0  3597.0  4200.0
# Books        777.0    549.380952   165.105360    96.0   470.0   500.0
# Personal     777.0   1340.642214   677.071454   250.0   850.0  1200.0
# PhD          777.0     72.660232    16.328155     8.0    62.0    75.0
# ...

# %%
cols = ["Top10perc", "Apps", "Enroll"]

pd.plotting.scatter_matrix(df[cols])
plt.tight_layout()
plt.show()

# %%
df.boxplot(column="Outstate", by="Private")
plt.tight_layout()
plt.show()

# %%
df["Elite"] = pd.cut(df["Top10perc"], [0, 50, 100], labels=["No", "Yes"])

df["Elite"].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
df.boxplot(column="Outstate", by="Elite")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2)
df["Outstate"].plot.hist(ax=ax[0,0], bins=30)
df["Books"].plot.hist(ax=ax[0,1], bins=30)
df["Accept"].plot.hist(ax=ax[1,0], bins=30)
df["PhD"].plot.hist(ax=ax[1,1], bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.isnull().sum()
# Out:
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# Elite          0
# dtype: int64

# %%
df.index.duplicated(keep=False).sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate', 'Elite'],
#       dtype='object')

# %%
cols = ["Apps", "Top10perc", "Top25perc", "PhD", "perc.alumni", "Elite"]
sb.pairplot(df[cols], hue="Elite")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9

# %%
df = pd.read_csv(r"../data/Auto.csv")

# %% [markdown]
# #### Verificando nulos e tipos

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df["horsepower"] = pd.to_numeric(
    df["horsepower"],
    errors="coerce"
)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
df.loc[df["horsepower"].isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 330  40.9          4          85.0         NaN    1835          17.3    80
# 336  23.6          4         140.0         NaN    2905          14.3    80
# 354  34.5          4         100.0         NaN    2320          15.8    81
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i

# %%
df = df.dropna()

# %% [markdown]
# #### a.)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
df.describe().T
# Out:
#               count         mean         std     min       25%      50%  \
# mpg           392.0    23.445918    7.805007     9.0    17.000    22.75
# cylinders     392.0     5.471939    1.705783     3.0     4.000     4.00
# displacement  392.0   194.411990  104.644004    68.0   105.000   151.00
# horsepower    392.0   104.469388   38.491160    46.0    75.000    93.50
# weight        392.0  2977.584184  849.402560  1613.0  2225.250  2803.50
# acceleration  392.0    15.541327    2.758864     8.0    13.775    15.50
# year          392.0    75.979592    3.683737    70.0    73.000    76.00
# origin        392.0     1.576531    0.805518     1.0     1.000     1.00
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   275.750   455.0
# horsepower     126.000   230.0
# weight        3614.750  5140.0
# acceleration    17.025    24.8
# year            79.000    82.0
# origin           2.000     3.0

# %%
df.nunique()
# Out:
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# year             13
# origin            3
# name            301
# dtype: int64

# %% [markdown]
# São quantitavas as preditoras: ["mpg", "displacement", "horsepower", "weight", "acceleration", "year"]
#
# São qualitativa as preditoas: ["origin", "name", "cylinders"]

# %% [markdown]
# #### b.)

# %%
cols = ["mpg", "displacement", "horsepower", "weight", "acceleration", "year"]
df[cols].agg(["min", "max"]).T
# Out:
#                  min     max
# mpg              9.0    46.6
# displacement    68.0   455.0
# horsepower      46.0   230.0
# weight        1613.0  5140.0
# acceleration     8.0    24.8
# year            70.0    82.0

# %% [markdown]
# #### c.)

# %%
df[cols].agg(["mean", "std"]).T
# Out:
#                      mean         std
# mpg             23.445918    7.805007
# displacement   194.411990  104.644004
# horsepower     104.469388   38.491160
# weight        2977.584184  849.402560
# acceleration    15.541327    2.758864
# year            75.979592    3.683737

# %% [markdown]
# #### d.)

# %%
df_out = pd.concat([
    df.iloc[:10, :],
    df.iloc[85:, :]
])
df_out[cols].describe().T[["min", "max", "mean", "std"]]
# Out:
#                  min     max         mean         std
# mpg             11.0    46.6    24.374763    7.872565
# displacement    68.0   455.0   187.880126  100.169973
# horsepower      46.0   230.0   101.003155   36.003208
# weight        1649.0  4997.0  2938.854890  811.640668
# acceleration     8.5    24.8    15.704101    2.719913
# year            70.0    82.0    77.123028    3.127158

# %% [markdown]
# #### e.)

# %%
sb.pairplot(df[cols].drop("year", axis=1))
plt.tight_layout()
plt.show()

# %% [markdown]
# #### f.)
#
# Os gráficos sugerem que as variáveis displacement, horsepower e weight estão associadas ao mpg de forma negativa, isto é, valores maiores dessas variáveis tendem a estar relacionados a menores valores de mpg. A relação observada não parece estritamente linear, possivelmente com curvatura, o que indica que transformações ou modelos não lineares podem ser apropriados.

# %% [markdown]
# ### 10.

# %% [markdown]
# #### a.)

# %%
from ISLP import load_data
import numpy as np

df = load_data("Boston")

# %% [markdown]
# #### b.)

# %%
df.shape
# Out:
# (506, 13)

# %%
df.head(3)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7

# %% [markdown]
# #### c.)

# %%
cols = ["indus", "nox", "rm", "age", "medv"]
sb.pairplot(df[cols])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### d.)

# %%
df.corr(method="kendall")["crim"].sort_values(ascending=False)[1:]
# Out:
# nox        0.603361
# rad        0.563969
# tax        0.544956
# indus      0.521014
# age        0.497297
# lstat      0.454837
# ptratio    0.312768
# chas       0.033948
# rm        -0.211718
# medv      -0.403964
# zn        -0.462057
# dis       -0.539878
# Name: crim, dtype: float64

# %% [markdown]
# #### e.)

# %%
df.sort_values("crim", ascending=False)
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.97620   0.0  18.10     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.53410   0.0  18.10     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.13580   0.0  18.10     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 55    0.01311  90.0   1.22     0  0.403  7.249   21.9  8.6966    5  226
# 341   0.01301  35.0   1.52     0  0.442  7.241   49.3  7.0379    1  284
# 285   0.01096  55.0   2.25     0  0.389  6.453   31.9  7.3073    1  300
# 284   0.00906  90.0   2.97     0  0.400  7.088   20.8  7.3073    1  285
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
#
#      ptratio  lstat  medv
# 380     20.2  17.21  10.4
# 418     20.2  20.62   8.8
# ...

# %%
df.boxplot(column="crim")
# Out:
# <Axes: >

# %% [markdown]
# #### f.)

# %%
df[df["chas"] == 1].shape[0]
# Out:
# 35

# %% [markdown]
# #### g.)

# %%
df["ptratio"].median()
# Out:
# 19.05

# %%
df.boxplot("ptratio")
# Out:
# <Axes: >

# %% [markdown]
# #### i.)

# %%
df["rm_floor"] = np.floor(df["rm"])

# %%
df["rm_floor"].value_counts()
# Out:
# rm_floor
# 6.0    269
# 5.0    158
# 7.0     51
# 8.0     13
# 4.0     13
# 3.0      2
# Name: count, dtype: int64

# %%
df[df["rm_floor"] == 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...
